# %%
# import  numpy  as  np 
# import matplotlib.pyplot as plt
# import pandas as pd 
# df = pd.read_csv("IRIS[1].csv") 
# df.head(10) 
# df.dropna()
import seaborn as sns
df=sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (150, 5)

# %%
df['species'].value_counts().plot(kind = "bar")
# Out:
# <Axes: >

# %%
#map function (dictionary)
df.species = df.species.map({'setosa':1 , 'versicolor':2, 'virginica':3})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
sns.pairplot(df, hue= 'species')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        1
# 1             4.9          3.0           1.4          0.2        1
# 2             4.7          3.2           1.3          0.2        1
# 3             4.6          3.1           1.5          0.2        1
# 4             5.0          3.6           1.4          0.2        1
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        3
# 146           6.3          2.5           5.0          1.9        3
# 147           6.5          3.0           5.2          2.0        3
# 148           6.2          3.4           5.4          2.3        3
# 149           5.9          3.0           5.1          1.8        3
#
# [150 rows x 5 columns]

# %%
x = df.drop(['species'], axis = 'columns')
y = df.species
print(x)
print(y)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 145    3
# 146    3
# 147    3
# 148    3
# 149    3
# Name: species, Length: 150, dtype: int64

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
from  sklearn.model_selection  import  train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.4)

# %%
x_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 109           7.2          3.6           6.1          2.5
# 89            5.5          2.5           4.0          1.3
# 45            4.8          3.0           1.4          0.3
# 38            4.4          3.0           1.3          0.2
# 97            6.2          2.9           4.3          1.3
# ..            ...          ...           ...          ...
# 138           6.0          3.0           4.8          1.8
# 58            6.6          2.9           4.6          1.3
# 98            5.1          2.5           3.0          1.1
# 107           7.3          2.9           6.3          1.8
# 120           6.9          3.2           5.7          2.3
#
# [90 rows x 4 columns]

# %%
x_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 14            5.8          4.0           1.2          0.2
# 53            5.5          2.3           4.0          1.3
# 10            5.4          3.7           1.5          0.2
# 130           7.4          2.8           6.1          1.9
# 132           6.4          2.8           5.6          2.2
# 52            6.9          3.1           4.9          1.5
# 93            5.0          2.3           3.3          1.0
# 60            5.0          2.0           3.5          1.0
# 18            5.7          3.8           1.7          0.3
# 7             5.0          3.4           1.5          0.2
# 105           7.6          3.0           6.6          2.1
# 126           6.2          2.8           4.8          1.8
# 17            5.1          3.5           1.4          0.3
# 92            5.8          2.6           4.0          1.2
# 143           6.8          3.2           5.9          2.3
# ...

# %%
from sklearn.svm import SVC

# %%
model = SVC()

# %%
rissh  = model.fit( x_train,y_train )

# %%
predictions = model.predict(x_test)

# %%
rissh.score(x_test,y_test)*100
# Out:
# 96.66666666666667

# %%
rissh.predict ([[ 5.8 , 4.0 , 1.2 , 0.2 ]])
# Out:
# C:\Users\vijaykumarj\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
rissh . predict ([[ 5.7 , 2.8 , 4.1 , 1.3 ]])
# Out:
# C:\Users\vijaykumarj\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# array([2], dtype=int64)

# %%
rissh . predict ([[ 6.3 , 2.5 , 5.0 , 1.9 ]])
# Out:
# C:\Users\vijaykumarj\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# array([3], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[22  0  0]
#  [ 0 17  2]
#  [ 0  0 19]]

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        22
#            2       1.00      0.89      0.94        19
#            3       0.90      1.00      0.95        19
#
#     accuracy                           0.97        60
#    macro avg       0.97      0.96      0.96        60
# weighted avg       0.97      0.97      0.97        60
